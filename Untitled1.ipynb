# %%
#1. Pick one of the datasets from the ChatBot session(s) of the TUT demo (or from your own ChatBot session if you wish) and use the code produced through the ChatBot interactions to import the data and confirm that the dataset has missing values

import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)
df.isna().sum()
# Out:
# row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# dtype: int64

# %%
#2. Start a new ChatBot session with an initial prompt introducing the dataset you're using and request help to determine how many columns and rows of data a pandas DataFrame has,

#（1）

import pandas as pd

# Load the dataset from the URL
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Get the column names
columns = df.columns.tolist()
print("Columns in the dataset:")
print(columns)

# Get the number of rows and columns
rows, columns_count = df.shape
print(f"\nNumber of rows: {rows}")
print(f"Number of columns: {columns_count}")

# View the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(df.head())

#（2）

#Observations defination: Individual data points or rows in a dataset, representing entities or units of analysis.
#Variables definition: Characteristics or columns that describe attributes of each observation.
# Out:
# Columns in the dataset:
# ['row_n', 'id', 'name', 'gender', 'species', 'birthday', 'personality', 'song', 'phrase', 'full_id', 'url']
#
# Number of rows: 391
# Number of columns: 11
#
# First few rows of the dataset:
#    row_n       id     name  gender    species birthday personality  \
# 0      2  admiral  Admiral    male       bird     1-27      cranky
# 1      3  agent-s  Agent S  female   squirrel      7-2       peppy
# 2      4    agnes    Agnes  female        pig     4-21        uchi
# 3      6       al       Al    male    gorilla    10-18        lazy
# 4      7  alfonso  Alfonso    male  alligator      6-9        lazy
#
#           song    phrase           full_id  \
# 0   Steep Hill   aye aye  villager-admiral
# 1      DJ K.K.  sidekick  villager-agent-s
# 2   K.K. House   snuffle    villager-agnes
# 3   Steep Hill   Ayyeeee       villager-al
# 4  Forest Life  it'sa me  villager-alfonso
#
#                                                  url
# ...

# %%
#3. Ask the ChatBot how you can provide simple summaries of the columns in the dataset and use the suggested code to provide these summaries for your dataset

import pandas as pd

# Load the dataset from the URL
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Display summary statistics for numerical columns
print("Summary Statistics for Numerical Columns:")
print(df.describe(include=[pd.np.number]))  # Note: `pd.np.number` is deprecated; use `include=[np.number]` if `np` is imported
print()

# Display summary statistics for categorical columns
print("Summary Statistics for Categorical Columns:")
print(df.describe(include=['object']))
print()

# Display the frequency distribution of a categorical column
# Replace 'column_name' with an actual column name from your dataset that is categorical
# For example, if 'species' is a categorical column:
print("Frequency Distribution for 'species':")
print(df['species'].value_counts())
print()

# Display the frequency distribution of another categorical column
# Replace 'column_name' with another actual column name
# For example, if 'personality' is a categorical column:
print("Frequency Distribution for 'personality':")
print(df['personality'].value_counts())
print()
# Out:
# Summary Statistics for Numerical Columns:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 11
#       9 # Display summary statistics for numerical columns
#      10 print("Summary Statistics for Numerical Columns:")
# ---> 11 print(df.describe(include=[pd.np.number]))  # Note: `pd.np.number` is deprecated; use `include=[np.number]` if `np` is imported
#      12 print()
#      14 # Display summary statistics for categorical columns
#
# AttributeError: module 'pandas' has no attribute 'np'

# %%
#4. If the dataset you're using has (a) non-numeric variables and (b) missing values in numeric variables, explain (perhaps using help from a ChatBot if needed) the discrepancies between size of the dataset given by df.shape and what is reported by df.describe() with respect to (a) the number of columns it analyzes and (b) the values it reports in the "count" column

#Import pandas and load the dataset:
import pandas as pd

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

#Display summary statistics for numerical columns:
print("Summary Statistics for Numerical Columns:")
print(df.describe())
print()

#Display summary statistics for categorical columns:
print("Summary Statistics for Categorical Columns:")
print(df.describe(include=['object']))
print()

#Display the frequency distribution of a categorical column:
# Example: Frequency distribution of the 'class' column
print("Frequency Distribution for 'class':")
print(df['class'].value_counts())
print()

# Example: Frequency distribution of the 'embarked' column
print("Frequency Distribution for 'embarked':")
print(df['embarked'].value_counts())
print()
# Out:
# Summary Statistics for Numerical Columns:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
# Summary Statistics for Categorical Columns:
#          sex embarked  class  who deck  embark_town alive
# count    891      889    891  891  203          889   891
# unique     2        3      3    3    7            3     2
# ...

# %%
#5. Use your ChatBot session to help understand the difference between the following and then provide your own paraphrasing summarization of that differenceFunctions in Programming:

#Definition of Functions in Programming: In programming, a function is a block of code designed to perform a specific task. It takes input values (arguments), processes them, and may return a result.
#definition of Functions in Mathematics: In mathematics, a function is a relation between a set of inputs and a set of outputs where each input is related to exactly one output. It's a rule or a formula that defines this relationship.

# %%
#6. The df.describe() method provides the 'count', 'mean', 'std', 'min', '25%', '50%', '75%', and 'max' summary statistics for each variable it analyzes. Give the definitions (perhaps using help from the ChatBot if needed) of each of these summary statistics

#Definition of Count:The number of non-null (non-missing) observations in the column. It shows how many values are present and usable for the calculation of other statistics.

#Definition of Mean:The arithmetic average of the values in the column. It is calculated by summing all the values and then dividing by the number of observations.

#Definition of Std (Standard Deviation):A measure of the amount of variation or dispersion in the column. It indicates how much the values deviate from the mean on average. A high standard deviation means the values are spread out from the mean.

#Definition of Min:The smallest value in the column. It provides the lower boundary of the data range.
    
#Definition of Percentile or First Quartile):The value below which 25% of the observations fall. It is also known as the first quartile (Q1) and helps identify the lower boundary of the data spread.

#definition of 50% (50th Percentile or Median):The middle value of the column when the data is sorted in ascending order. It divides the data into two equal halves. This is also known as the median.

#Definition of 75% (75th Percentile or Third Quartile):The value below which 75% of the observations fall. It is also known as the third quartile (Q3) and indicates the upper boundary of the data spread.

#DefinitionMax:The largest value in the column. It provides the upper boundary of the data range.

# %%
#7. Missing data can be considered "across rows" or "down columns". Consider how df.dropna() or del df['col'] should be applied to most efficiently use the available non-missing data in your dataset and briefly answer the following questions in your own words

#(1)
import pandas as pd

# Sample data
data = {
    'customer_id': [1, 2, 3, 4, 5],
    'purchase_amount': [100, 200, None, 150, None],
    'purchase_date': ['2024-01-01', '2024-01-02', None, '2024-01-04', '2024-01-05'],
    'discount_code': ['DISC10', None, 'DISC20', 'DISC30', None],
    'feedback': [None, 'Great', None, 'Good', None]
}

df = pd.DataFrame(data)

# Using df.dropna() to remove rows with missing values in critical columns
df_cleaned = df.dropna(subset=['purchase_amount', 'purchase_date'])

print("Cleaned DataFrame:")
print(df_cleaned)

#(2)
import pandas as pd

# Sample data
data = {
    'timestamp': ['2024-01-01 00:00', '2024-01-01 01:00', '2024-01-01 02:00', '2024-01-01 03:00', '2024-01-01 04:00'],
    'temperature': [22.5, 23.0, None, 22.8, 23.1],
    'humidity': [55, None, 53, 54, None],
    'vibration': [0.5, 0.6, None, 0.7, 0.5],
    'status': [None, 'OK', None, None, 'Faulty']
}

df = pd.DataFrame(data)

# Removing the 'status' column as it has excessive missing values
del df['status']

print("DataFrame after removing the 'status' column:")
print(df)

#(3)
import pandas as pd

# Sample data with some columns having excessive missing values
data = {
    'timestamp': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'temperature': [22.5, None, 23.0, 22.8, None],
    'humidity': [None, 55.0, None, 54.0, None],
    'vibration': [0.5, 0.6, None, 0.7, 0.5],
    'status': [None, None, None, None, None]  # Column with excessive missing values
}

df = pd.DataFrame(data)

# Remove the 'status' column which has excessive missing values
del df['status']

# Apply dropna() to remove rows with missing values in remaining columns
df_cleaned = df.dropna()

print("Cleaned DataFrame:")
print(df_cleaned)

#Summary
#Applying del df['col'] before df.dropna() helps in managing data more efficiently and effectively. It ensures that you are not unnecessarily removing rows due to columns with excessive missing values, focuses your cleaning process on relevant columns, and optimizes both processing speed and memory usage. This approach improves the quality and usability of the dataset for analysis.

#(4)
import pandas as pd

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

# Display the first few rows of the dataset
print("Original DataFrame:")
print(df.head())
print("\nSummary of missing values in the original dataset:")
print(df.isna().sum())

#example
import pandas as pd

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

# Display the original DataFrame and missing values summary
print("Original DataFrame:")
print(df.head())
print("\nSummary of missing values in the original dataset:")
print(df.isna().sum())

# Remove columns with excessive missing values
# For this example, let's assume 'deck' and 'embark_town' have too many missing values
columns_to_remove = ['deck', 'embark_town']
for col in columns_to_remove:
    if col in df.columns:
        del df[col]

# Apply dropna() to remove rows with missing values in the remaining columns
df_cleaned = df.dropna()

# Display the cleaned DataFrame and missing values summary
print("\nCleaned DataFrame:")
print(df_cleaned.head())
print("\nSummary of missing values in the cleaned dataset:")
print(df_cleaned.isna().sum())
# Out:
# Cleaned DataFrame:
#    customer_id  purchase_amount purchase_date discount_code feedback
# 0            1            100.0    2024-01-01        DISC10     None
# 1            2            200.0    2024-01-02          None    Great
# 3            4            150.0    2024-01-04        DISC30     Good
# DataFrame after removing the 'status' column:
#           timestamp  temperature  humidity  vibration
# 0  2024-01-01 00:00         22.5      55.0        0.5
# 1  2024-01-01 01:00         23.0       NaN        0.6
# 2  2024-01-01 02:00          NaN      53.0        NaN
# 3  2024-01-01 03:00         22.8      54.0        0.7
# 4  2024-01-01 04:00         23.1       NaN        0.5
# Cleaned DataFrame:
#     timestamp  temperature  humidity  vibration
# 3  2024-01-04         22.8      54.0        0.7
# Original DataFrame:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# ...

# %%
#8. Give brief explanations in your own words for any requested answers to the questions below
import pandas as pd

# Load the dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())
# Check for missing values
print(df.isnull().sum())
# Summary statistics for numerical columns
print(df.describe())

# Summary statistics for categorical columns
print(df.describe(include=['object']))

# General info about the DataFrame
print(df.info())
import seaborn as sns
import matplotlib.pyplot as plt

# Plot a count plot of survival status
sns.countplot(x='survived', data=df)
plt.title('Survival Count')
plt.show()

# Plot a bar plot of survival by class
sns.barplot(x='class', y='survived', data=df)
plt.title('Survival Rate by Class')
plt.show()

# Plot a histogram of ages
sns.histplot(df['age'].dropna(), bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

# Plot a heatmap to visualize missing data
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

#(1）

import pandas as pd

# Load the dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)

# Group by the 'class' column and get descriptive statistics for the 'age' column
age_stats_by_class = df.groupby('class')['age'].describe()

print(age_stats_by_class)

#Explanation
#Grouping by Class: df.groupby('class') groups the DataFrame by the values in the class column. So, you get separate groups for each class (First, Second, Third).

#Selecting Age: ['age'] selects the age column within each group.

#Descriptive Statistics: .describe() calculates statistics such as count, mean, standard deviation, minimum, maximum, and quartiles for age within each class group.

#(2)
#The difference in the count values between df.describe() and df.groupby("col1")["col2"].describe() when dealing with missing data stems from the scope and context of the descriptive statistics being calculated.
#Key Differences:
#Scope of Aggregation:df.describe(): Provides statistics for the entire DataFrame column.df.groupby("col1")["col2"].describe(): Provides statistics for each subgroup defined by col1.
#Missing Data Context:In df.describe(): The count represents the number of non-null entries for each column overall, which might be reduced if there are missing values.In df.groupby("col1")["col2"].describe(): The count is specific to each group and will vary based on how missing values are distributed among groups.
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# ...

# %%
#9.Have you reviewed the course wiki-textbook and interacted with a ChatBot (or, if that wasn't sufficient, real people in the course piazza discussion board or TA office hours) to help you understand all the material in the tutorial and lecture that you didn't quite follow when you first saw it?
#Answer: Mostly.

# %% [markdown]
# Summary of Interactions
# 1. Dataset Overview and Dimensions
#
# We discussed a dataset from Animal Crossing, focusing on the columns and dimensions of the dataset.
# You learned to use df.shape to understand the size of the dataset and df.describe() to get summary statistics.
# 2. Summary Statistics from df.describe()
#
# Count: Number of non-missing values.
# Mean: Average of the values.
# Std (Standard Deviation): Measure of the spread or dispersion of the values.
# Min: Smallest value.
# 25% (Q1): First quartile, the value below which 25% of the data falls.
# 50% (Median): Middle value that divides the data into two halves.
# 75% (Q3): Third quartile, the value below which 75% of the data falls.
# Max: Largest value.
# 3. Handling Missing Data
#
# df.dropna(): Removes rows (or columns) with missing values. Used to ensure that all data is complete, but can lead to significant data loss if many rows are affected.
# del df['col']: Removes specific columns. Useful when a column has excessive missing data or is not relevant, preventing complications in analysis.
# 4. Example of Using df.dropna()
#
# Use Case: Customer satisfaction survey analysis. Focused on ensuring complete data for critical columns (SatisfactionScore), while potentially retaining less critical columns with missing data.
# 5. Example of Using del df['col']
#
# Use Case: Employee performance metrics. Removed a column (ManagerFeedback) with excessive missing values, simplifying the dataset and focusing on critical columns for performance analysis.
# 6. Combined Approach: del df['col'] before df.dropna()
#
# Justification: Removing irrelevant or excessively incomplete columns first helps simplify the dataset and avoid unnecessary data loss. After column removal, df.dropna() can be used more effectively to handle missing values in the remaining important columns.
# 7. Practical Application
#
# Provided an example of removing missing data from a sample dataset using both del df['col'] and df.dropna(), including a before and after report of the dataset to illustrate the effects of these operations.
#
#
#
# https://chatgpt.com/share/7928484b-d06d-4b1b-ba76-74acaeef4c6e
